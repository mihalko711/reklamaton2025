# %%
from together import Together
import base64
import os
# Out:
# Конечно, вот несколько советов, как улучшить фотографию для сайта знакомств, учитывая предоставленное изображение:
#
# **Общие советы:**
#
# *   **Освещение:** На данном фото освещение немного неравномерное. Лучше всего, если свет будет мягким и рассеянным, например, дневным светом из окна. Избегайте прямого солнечного света, который может создавать резкие тени.
# *   **Фон:** Фон немного отвлекающий с наклейками и телевизором.  Идеально, если фон будет нейтральным и не перегруженным деталями.  Можно выбрать однотонную стену или естественный пейзаж.
# *   **Улыбка:**  Улыбка делает человека более привлекательным и доступным.  Попробуйте немного расслабить лицо и улыбнуться искренне. Даже легкая улыбка гораздо лучше, чем нейтральное выражение лица.
# *   **Качество:**  Убедитесь, что фото высокого разрешения. Размытые или пиксельные фотографии не производят хорошего впечатления.
# ...

# %%
path_to_pict = '/home/undefinedname/reklamaton/pict'
client = Together(api_key = os.environ.get('TOGETHER_API_KEY'))
prompt = "дай совет по тому, как улучшить этому человеку фотографию для сайта знакомств... КРАТКО: пара - пятерка советов в пару предложений"
for root, dir_, filenames in os.walk(path_to_pict):
    for file in filenames:
        response = client.chat.completions.create(
        model="google/gemma-3n-E4B-it",
        messages=[
            {
                "role": "user",
                "content": [
                    {
                        "type": "image_url",
                        "image_url": {
                            "url": f"https://raw.githubusercontent.com/mihalko711/reklamaton2025/main/pict/{file}"
                            
                        }
                    },
                    {
                        "type": "text",
                        "text": prompt
                    }
                ]
            }
        ]
        
        )

        print(response.choices[0].message.content)
# Out:
# Конечно, вот 5 советов для улучшения фотографии для сайта знакомств:
#
# 1. **Больше света:** Естественное освещение делает лицо более привлекательным. Старайтесь фотографироваться при дневном свете, избегая прямого солнца.
# 2. **Улыбка:** Искренняя улыбка располагает к общению и показывает вашу дружелюбность.
# 3. **Фон:** Выберите простой, не отвлекающий фон. Он не должен перетягивать внимание от вас.
# 4. **Качество:** Используйте камеру с хорошим разрешением. Размытые фотографии не производят хорошего впечатления.
# 5. **Разнообразие:** Добавьте фотографии, где вы занимаетесь своими увлечениями. Это покажет вашу личность и интересы.
# Конечно, вот 5 советов для улучшения фотографии к сайту знакомств:
#
# 1.  **Больше света:** Естественный свет - лучший друг! Попробуйте фотографироваться при дневном свете у окна, чтобы лицо было хорошо освещено.
# 2.  **Улыбка:** Ваша улыбка должна быть искренней и располагающей. Подумайте о чем-то приятном, чтобы улыбка выглядела естественной.
# ...
